# %%
import pandas as pd
import numpy as np

tumor_data = pd.read_csv("Tumor_data.csv")
tumor_data
# Out:
#      radius  texture  perimeter    area  smoothness
# 0     17.99    10.38     122.80  1001.0     0.11840
# 1     20.57    17.77     132.90  1326.0     0.08474
# 2     19.69    21.25     130.00  1203.0     0.10960
# 3     11.42    20.38      77.58   386.1     0.14250
# 4     20.29    14.34     135.10  1297.0     0.10030
# ..      ...      ...        ...     ...         ...
# 564   21.56    22.39     142.00  1479.0     0.11100
# 565   20.13    28.25     131.20  1261.0     0.09780
# 566   16.60    28.08     108.30   858.1     0.08455
# 567   20.60    29.33     140.10  1265.0     0.11780
# 568    7.76    24.54      47.92   181.0     0.05263
#
# [569 rows x 5 columns]

# %%
parameter_means = tumor_data.mean(numeric_only=True)

print("\nMean of all parameters:")
print(parameter_means)
# Out:
# Mean of all parameters:
# radius         14.127292
# texture        19.289649
# perimeter      91.969033
# area          654.889104
# smoothness      0.096360
# dtype: float64

# %%
mean_radius = parameter_means['radius']

large_radius_tumors = tumor_data[tumor_data['radius'] > mean_radius]
print(large_radius_tumors)
# Out:
#      radius  texture  perimeter    area  smoothness
# 0     17.99    10.38      122.8  1001.0     0.11840
# 1     20.57    17.77      132.9  1326.0     0.08474
# 2     19.69    21.25      130.0  1203.0     0.10960
# 4     20.29    14.34      135.1  1297.0     0.10030
# 6     18.25    19.98      119.6  1040.0     0.09463
# ..      ...      ...        ...     ...         ...
# 563   20.92    25.09      143.0  1347.0     0.10990
# 564   21.56    22.39      142.0  1479.0     0.11100
# 565   20.13    28.25      131.2  1261.0     0.09780
# 566   16.60    28.08      108.3   858.1     0.08455
# 567   20.60    29.33      140.1  1265.0     0.11780
#
# [226 rows x 5 columns]

# %%
mean_radius=tumor_data['radius'].median()
median_perimeter=tumor_data['perimeter'].median()
special_tumors=tumor_data[(tumor_data['radius']<mean_radius)&(tumor_data['perimeter']>median_perimeter)]
special_tumors
# Out:
#      radius  texture  perimeter   area  smoothness
# 8     13.00    21.82      87.50  519.8     0.12730
# 43    13.28    20.28      87.32  545.2     0.10410
# 81    13.34    15.86      86.49  520.0     0.10780
# 105   13.11    15.56      87.21  530.2     0.13980
# 208   13.11    22.54      87.02  529.4     0.10020
# 465   13.24    20.13      86.87  542.9     0.08284

# %%
wine_data = pd.read_excel("Wine_data.xlsx")
wine_data
# Out:
#      Alcohol  Malic Acid   Ash  Alcalinity of Ash  Magnesium  Total Phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
# Calculate median values for alcohol and magnesium
alcohol_median = wine_data['Alcohol'].median()
magnesium_median = wine_data['Magnesium'].median()

# Filter wines where alcohol > median AND magnesium < median
high_alcohol_low_magnesium = wine_data[
    (wine_data['Alcohol'] > alcohol_median) & 
    (wine_data['Magnesium'] < magnesium_median)
]

print("\nWines with high alcohol but low magnesium:")
print(f"Alcohol median: {alcohol_median:.2f}, Magnesium median: {magnesium_median:.2f}")
print(high_alcohol_low_magnesium)
# Out:
# Wines with high alcohol but low magnesium:
# Alcohol median: 13.05, Magnesium median: 98.00
#      Alcohol  Malic Acid   Ash  Alcalinity of Ash  Magnesium  Total Phenols  \
# 6      14.39        1.87  2.45               14.6         96           2.50
# 8      14.83        1.64  2.17               14.0         97           2.80
# 11     14.12        1.48  2.32               16.8         95           2.20
# 12     13.75        1.73  2.41               16.0         89           2.60
# 13     14.75        1.73  2.39               11.4         91           3.10
# 24     13.50        1.81  2.61               20.0         96           2.53
# 26     13.39        1.77  2.62               16.1         93           2.85
# 27     13.30        1.72  2.14               17.0         94           2.40
# 29     14.02        1.68  2.21               16.0         96           2.65
# 41     13.41        3.84  2.12               18.8         90           2.45
# ...

# %%
share_data = pd.read_csv("Share_data.csv")
share_data
# Out:
#     Day  Opening Price  Closing Price
# 0     1             10             12
# 1     2             13             15
# 2     3             11             14
# 3     4             13             11
# 4     5             10              9
# 5     6             11             12
# 6     7             11             13
# 7     8             12             11
# 8     9             10             14
# 9    10             13             15
# 10   11             15             17
# 11   12             16             15
# 12   13             15             14
# 13   14             15             16
# 14   15             16             18
# 15   16             17             18
# 16   17             17             19
# 17   18             19             17
# 18   19             17             17
# 19   20             18             20

# %%
from scipy import stats

opening_mean = share_data['Opening Price'].mean()
opening_median = share_data['Opening Price'].median()
opening_mode = stats.mode(share_data['Opening Price'])

closing_mean = share_data['Closing Price'].mean()
closing_median = share_data['Closing Price'].median()
closing_mode = stats.mode(share_data['Closing Price'])

# %%
import seaborn as sns

# %%
dataset = sns.get_dataset_names()
dataset
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
da = sns.load_dataset("titanic")
da
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
def bubble_sort(students):
    n = len(students)
    for i in range(n):
        for j in range(0, n-i-1):
            # Compare marks
            if students[j][1] < students[j+1][1]:
                students[j], students[j+1] = students[j+1], students[j]
            # If marks are equal, compare names in DESCENDING order
            elif students[j][1] == students[j+1][1] and students[j][0] < students[j+1][0]:
                students[j], students[j+1] = students[j+1], students[j]
    return students

if __name__ == "__main__":
    n = int(input())
    students = []
    for _ in range(n):
        line = input().strip().split()
        name = line[0]
        marks = int(line[1])
        students.append((name, marks))

    sorted_students = bubble_sort(students)

    for student in sorted_students:
        print(student[0], student[1])
# Out:
#  2
#  ALice 85
#  Bob 85
# Bob 85
# ALice 85
