# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MaxAbsScaler

# %%
tumor = pd.read_csv("Tumor_data.csv")
tumor
# Out:
#      radius  texture  perimeter    area  smoothness
# 0     17.99    10.38     122.80  1001.0     0.11840
# 1     20.57    17.77     132.90  1326.0     0.08474
# 2     19.69    21.25     130.00  1203.0     0.10960
# 3     11.42    20.38      77.58   386.1     0.14250
# 4     20.29    14.34     135.10  1297.0     0.10030
# ..      ...      ...        ...     ...         ...
# 564   21.56    22.39     142.00  1479.0     0.11100
# 565   20.13    28.25     131.20  1261.0     0.09780
# 566   16.60    28.08     108.30   858.1     0.08455
# 567   20.60    29.33     140.10  1265.0     0.11780
# 568    7.76    24.54      47.92   181.0     0.05263
#
# [569 rows x 5 columns]

# %%
mean=tumor.mean()
mean
# Out:
# radius         14.127292
# texture        19.289649
# perimeter      91.969033
# area          654.889104
# smoothness      0.096360
# dtype: float64

# %%
mean_radius = tumor['radius'].mean()
gt_mean_radius = tumor[tumor['radius']>mean_radius]
print(gt_mean_radius)
# Out:
#      radius  texture  perimeter    area  smoothness
# 0     17.99    10.38      122.8  1001.0     0.11840
# 1     20.57    17.77      132.9  1326.0     0.08474
# 2     19.69    21.25      130.0  1203.0     0.10960
# 4     20.29    14.34      135.1  1297.0     0.10030
# 6     18.25    19.98      119.6  1040.0     0.09463
# ..      ...      ...        ...     ...         ...
# 563   20.92    25.09      143.0  1347.0     0.10990
# 564   21.56    22.39      142.0  1479.0     0.11100
# 565   20.13    28.25      131.2  1261.0     0.09780
# 566   16.60    28.08      108.3   858.1     0.08455
# 567   20.60    29.33      140.1  1265.0     0.11780
#
# [226 rows x 5 columns]

# %%
mean_radius = tumor['radius'].mean()
gt_mean_radius = tumor[tumor['radius'] > mean_radius]
print(gt_mean_radius)
# Out:
#      radius  texture  perimeter    area  smoothness
# 0     17.99    10.38      122.8  1001.0     0.11840
# 1     20.57    17.77      132.9  1326.0     0.08474
# 2     19.69    21.25      130.0  1203.0     0.10960
# 4     20.29    14.34      135.1  1297.0     0.10030
# 6     18.25    19.98      119.6  1040.0     0.09463
# ..      ...      ...        ...     ...         ...
# 563   20.92    25.09      143.0  1347.0     0.10990
# 564   21.56    22.39      142.0  1479.0     0.11100
# 565   20.13    28.25      131.2  1261.0     0.09780
# 566   16.60    28.08      108.3   858.1     0.08455
# 567   20.60    29.33      140.1  1265.0     0.11780
#
# [226 rows x 5 columns]

# %%
mean_radius = tumor['radius'].mean()
mean_perimeter = tumor['perimeter'].mean()


lt_mean_radius_gt_perimeter = tumor[(tumor['radius'] < mean_radius) & (tumor['perimeter'] > mean_perimeter)]

print(lt_mean_radius_gt_perimeter)
# Out:
#      radius  texture  perimeter   area  smoothness
# 14    13.73    22.61      93.60  578.3      0.1131
# 501   13.82    24.49      92.33  595.9      0.1162

# %%
wine = pd.read_excel('Wine_data.xlsx')
wine
# Out:
#      Alcohol  Malic Acid   Ash  Alcalinity of Ash  Magnesium  Total Phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
alc_content = wine['Alcohol'].median()
mag_content = wine['Magnesium'].median()
best_alc = wine[(wine['Alcohol']>alc_content) & (wine['Magnesium']<mag_content)]

print(best_alc)
# Out:
#      Alcohol  Malic Acid   Ash  Alcalinity of Ash  Magnesium  Total Phenols  \
# 6      14.39        1.87  2.45               14.6         96           2.50
# 8      14.83        1.64  2.17               14.0         97           2.80
# 11     14.12        1.48  2.32               16.8         95           2.20
# 12     13.75        1.73  2.41               16.0         89           2.60
# 13     14.75        1.73  2.39               11.4         91           3.10
# 24     13.50        1.81  2.61               20.0         96           2.53
# 26     13.39        1.77  2.62               16.1         93           2.85
# 27     13.30        1.72  2.14               17.0         94           2.40
# 29     14.02        1.68  2.21               16.0         96           2.65
# 41     13.41        3.84  2.12               18.8         90           2.45
# 51     13.83        1.65  2.60               17.2         94           2.45
# ...

# %%
maax = wine['Hue'].max()
miin = wine['Hue'].min()

rangee = maax-miin

print("Range of hue is ",rangee)
# Out:
# Range of hue is  1.23

# %%
correlation = wine['Alcohol'].corr(wine[' Colour Intensity'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.5463641950837039

# %%
share = pd.read_csv("Share_data.csv")
share
# Out:
#     Day  Opening Price  Closing Price
# 0     1             10             12
# 1     2             13             15
# 2     3             11             14
# 3     4             13             11
# 4     5             10              9
# 5     6             11             12
# 6     7             11             13
# 7     8             12             11
# 8     9             10             14
# 9    10             13             15
# 10   11             15             17
# 11   12             16             15
# 12   13             15             14
# 13   14             15             16
# 14   15             16             18
# 15   16             17             18
# 16   17             17             19
# 17   18             19             17
# 18   19             17             17
# 19   20             18             20

# %%
mean_o = share['Opening Price'].mean()
mean_c = share['Closing Price'].mean()

print('Mean of opening',mean_o)

print('Mean of closing',mean_c)
# Out:
# Mean of opening 13.95
# Mean of closing 14.85

# %%
median_o = share['Opening Price'].median()
median_c = share['Closing Price'].median()

print('Median of opening',median_o)

print('Median of closing',median_c)
# Out:
# Median of opening 14.0
# Median of closing 15.0

# %%
mode_o = share['Opening Price'].mode()
mode_c = share['Closing Price'].mode()

print('Mode of opening',mode_o)

print('Mode of closing',mode_c)
# Out:
# Mode of opening 0    10
# 1    11
# 2    13
# 3    15
# 4    17
# Name: Opening Price, dtype: int64
# Mode of closing 0    14
# 1    15
# 2    17
# Name: Closing Price, dtype: int64

# %%
sd_o = np.std(share['Opening Price'])
sd_c = np.std(share['Closing Price'])



print("Std of opening",sd_o)
print("Std of closing",sd_c)
# Out:
# Std of opening 2.836811590500857
# Std of closing 2.8683619018526936

# %%
#rmse
x = share['Opening Price']
y = share['Closing Price']

best_fit = np.polyfit(x,y,1)

predicted_val = np.polyval(best_fit,x)

rmse= np.sqrt(np.mean((y-predicted_val)**2))

print("Best Fit is ",rmse)
# Out:
# Best Fit is  1.605732972314631

# %%
emp = pd.read_excel("Emp_info (1).xlsx")
emp
# Out:
#       id    city        dept  age   salary  performance score
# 0   A001  Mumbai       sales   23  1800000                1.4
# 1   A002   Delhi  technology   35  2500000                7.0
# 2   A003   Delhi  production   22  1000000                3.8
# 3   A004  Indore       sales   34  2200000                2.5
# 4   A005  Mumbai  technology   31   800000                9.0
# 5   A006  Mumbai  production   26  1700000                3.7
# 6   A007   Delhi       sales   28   600000                1.9
# 7   A009    Pune       sales   40   700000                9.7
# 8   A010   Delhi  technology   45  3000000                4.4
# 9   A011  Mumbai  technology   33   280000                5.6
# 10  A012    Pune   marketing   33   230000                7.0
# 11  A013  Indore  production   42  2600000                3.8
# 12  A014   Delhi  production   27  3400000                8.5
# 13  A015  Mumbai       sales   27   300000                7.3
# ...

# %%
scaler = MaxAbsScaler()

scaled_data = scaler.fit_transform(emp)
scaled_df = pd.emp(scaled_data, columns=data.columns)
print(scaled_emp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12356\3392033205.py in <module>
#       1 scaler = MaxAbsScaler()
#       2
# ----> 3 scaled_data = scaler.fit_transform(emp)
#       4 scaled_df = pd.emp(scaled_data, columns=data.columns)
#       5 print(scaled_df)
#
# E:\anaconda1\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# E:\anaconda1\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#    1148         # Reset internal state before fitting
#    1149         self._reset()
# -> 1150         return self.partial_fit(X, y)
# ...
