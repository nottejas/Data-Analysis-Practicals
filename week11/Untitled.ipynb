# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("sample_dataset.csv")
df
# Out:
#        Customer ID       Name    Surname Gender   Birthdate  \
# 0           752858       Sean  Rodriguez      F  2002-10-20
# 1            26381   Michelle     Phelps    NaN  1985-10-24
# 2           305449      Jacob   Williams      M  1981-10-25
# 3           988259     Nathan     Snyder      M  1977-10-26
# 4           764762    Crystal      Knapp      F  1951-11-02
# ...            ...        ...        ...    ...         ...
# 49995       891845  Christine      Leach      F  1997-10-21
# 49996       800560       Anna      Allen      F  1999-10-21
# 49997       133285     Nicole   Franklin      M  1979-10-26
# 49998       616122      Maria     Keller      M  1981-10-25
# 49999       832184      Billy     Walker      F  1958-10-31
#
#        Transaction Amount        Date                 Merchant Name  \
# 0                   35.47  2023-04-03                 Smith-Russell
# 1                 2552.72  2023-07-17        Peck, Spence and Young
# ...

# %%
df.nunique()
# Out:
# Customer ID           50000
# Name                    690
# Surname                1000
# Gender                    2
# Birthdate                58
# Transaction Amount    34665
# Date                    287
# Merchant Name         36939
# Category                  6
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           50000 non-null  object
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  object
#  7   Merchant Name       50000 non-null  object
#  8   Category            50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB

# %%
trans_ams = df['Transaction Amount'].to_numpy()

# %%
mean = np.mean(trans_ams)
median = np.median(trans_ams)
median
# Out:
# 182.195

# %%
group_d = df.groupby('Customer ID')['Transaction Amount'].sum()
group_d
# Out:
# Customer ID
# 29          27.02
# 51        1898.56
# 54         166.30
# 83         125.85
# 90          18.16
#            ...
# 999904     266.06
# 999914     295.11
# 999942     153.78
# 999949     636.09
# 999997      15.47
# Name: Transaction Amount, Length: 50000, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df["Transaction Amount"], bins=30, kde=True)
plt.xlabel("Category")
plt.ylabel("Total trans amount")
plt.show()

# %%
ct = pd.crosstab(df['Name'], df['Gender'], margins=True)
ct
# Out:
# Gender       F      M    All
# Name
# Aaron       86     63    149
# Abigail     28     26     54
# Adam        79     86    165
# Adrian      17     17     34
# Adriana      2      4      6
# ...        ...    ...    ...
# Yvette       5      5     10
# Yvonne      13     10     23
# Zachary     65     65    130
# Zoe          1      2      3
# All      22713  22240  44953
#
# [691 rows x 3 columns]

# %%
df.dtypes
# Out:
# Customer ID             int64
# Name                   object
# Surname                object
# Gender                 object
# Birthdate              object
# Transaction Amount    float64
# Date                   object
# Merchant Name          object
# Category               object
# dtype: object

# %%
num_data = df.select_dtypes(include=[np.number])

corr_m = num_data.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr_m, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("asas")
plt.show()

# %%
df.isnull().sum()/len(df)*100
# Out:
# Customer ID            0.000
# Name                   0.000
# Surname                0.000
# Gender                10.094
# Birthdate              0.000
# Transaction Amount     0.000
# Date                   0.000
# Merchant Name          0.000
# Category               0.000
# dtype: float64

# %%
sns.pairplot(df, hue='Category')
plt.title("Asas")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='Date', y='Transaction Amount', data=df)
plt.title("Aasas")
plt.show()
